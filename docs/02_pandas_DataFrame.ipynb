# %% [markdown]
# <a href="https://colab.research.google.com/github/SeokcheonMoon/study_data_analytics/blob/main/docs/02_pandas_DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# ## Pandas

# %% [markdown]
# ### DataFrame(데이터 프레임)  = (Series + Series + Series + ...) + column
#
#
# *   다(복합)변수

# %%
list = [3,4,5,6]
pd.DataFrame(list)
# Out:
#    0
# 0  3
# 1  4
# 2  5
# 3  6

# %%
pd.Series(list)
# Out:
# 0    3
# 1    4
# 2    5
# 3    6
# dtype: int64

# %%
double_list = [
             [1000, '과자','2019-12-31','반품'],
             [2000, '음료', '2020-03-02', '정상'],
             [3000, '아이스크림', '2020-02-03','정상'],
             [1000,'과자','2019-12-31','반품']
]
double_columns = ['가격','종류','판매일자','반품여부']
pd.DataFrame(data=double_list, columns=double_columns)
# Out:
#      가격     종류        판매일자 반품여부
# 0  1000     과자  2019-12-31   반품
# 1  2000     음료  2020-03-02   정상
# 2  3000  아이스크림  2020-02-03   정상
# 3  1000     과자  2019-12-31   반품

# %% [markdown]
# #### 내용 확인

# %%
df_saledays = pd.DataFrame(data=double_list, columns=double_columns)
type(df_saledays), df_saledays.shape
# Out:
# (pandas.core.frame.DataFrame, (4, 4))

# %%
df_saledays.index, df_saledays.columns, df_saledays.values          # dataframe 분해
# Out:
# (RangeIndex(start=0, stop=4, step=1),
#  Index(['가격', '종류', '판매일자', '반품여부'], dtype='object'),
#  array([[1000, '과자', '2019-12-31', '반품'],
#         [2000, '음료', '2020-03-02', '정상'],
#         [3000, '아이스크림', '2020-02-03', '정상'],
#         [1000, '과자', '2019-12-31', '반품']], dtype=object))

# %%
type(df_saledays.columns)
# Out:
# pandas.core.indexes.base.Index

# %% [markdown]
# #### 간편 확인

# %%
df_saledays.head(2)
# Out:
#      가격  종류        판매일자 반품여부
# 0  1000  과자  2019-12-31   반품
# 1  2000  음료  2020-03-02   정상

# %%
df_saledays[:2]
# Out:
#      가격  종류        판매일자 반품여부
# 0  1000  과자  2019-12-31   반품
# 1  2000  음료  2020-03-02   정상

# %%
df_saledays[-2:]
# Out:
#      가격     종류        판매일자 반품여부
# 2  3000  아이스크림  2020-02-03   정상
# 3  1000     과자  2019-12-31   반품

# %% [markdown]
# #### 데이터 정보 확인

# %%
df_saledays.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   가격      4 non-null      int64
#  1   종류      4 non-null      object
#  2   판매일자    4 non-null      object
#  3   반품여부    4 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 256.0+ bytes

# %%
df_saledays.describe()                    # object는 발견 x
# Out:
#                 가격
# count     4.000000
# mean   1750.000000
# std     957.427108
# min    1000.000000
# 25%    1000.000000
# 50%    1500.000000
# 75%    2250.000000
# max    3000.000000

# %%
df_saledays.columns
# Out:
# Index(['가격', '종류', '판매일자', '반품여부'], dtype='object')

# %%
df_saledays["종류"]
# Out:
# 0       과자
# 1       음료
# 2    아이스크림
# 3       과자
# Name: 종류, dtype: object

# %%
df_saledays["종류"].unique()
# Out:
# array(['과자', '음료', '아이스크림'], dtype=object)

# %%
df_saledays["반품여부"].unique()
# Out:
# array(['반품', '정상'], dtype=object)

# %% [markdown]
# ## 전처리

# %% [markdown]
# ### 추출

# %%
df_saledays
# Out:
#      가격     종류        판매일자 반품여부
# 0  1000     과자  2019-12-31   반품
# 1  2000     음료  2020-03-02   정상
# 2  3000  아이스크림  2020-02-03   정상
# 3  1000     과자  2019-12-31   반품

# %% [markdown]
# #### 컬럼단위

# %%
df_saledays.columns
# Out:
# Index(['가격', '종류', '판매일자', '반품여부'], dtype='object')

# %%
df_saledays["가격"]                     # series 추출
series_price = df_saledays["가격"]
series_price.shape, type(series_price)
# Out:
# ((4,), pandas.core.series.Series)

# %%
df_saledays[["종류","판매일자"]]        # dataframe 추출
# Out:
#       종류        판매일자
# 0     과자  2019-12-31
# 1     음료  2020-03-02
# 2  아이스크림  2020-02-03
# 3     과자  2019-12-31

# %%
df_saledays[["종류","판매일자"]].shape
# Out:
# (4, 2)

# %%
type(df_saledays[["종류","판매일자"]])
# Out:
# pandas.core.frame.DataFrame

# %%
df_saledays[["종류","판매일자"]].value_counts()
# Out:
# 종류     판매일자
# 과자     2019-12-31    2
# 아이스크림  2020-02-03    1
# 음료     2020-03-02    1
# dtype: int64

# %% [markdown]
# #### row(index) 단위 : iloc vs loc
# - iloc : 위치값으로 접근
# - loc : 명칭으로 접근

# %%
df_saledays
# Out:
#      가격     종류        판매일자 반품여부
# 0  1000     과자  2019-12-31   반품
# 1  2000     음료  2020-03-02   정상
# 2  3000  아이스크림  2020-02-03   정상
# 3  1000     과자  2019-12-31   반품

# %%
df_saledays.index = ['a','b','c','d']

# %%
df_saledays.iloc[2], df_saledays.loc["c"]
# Out:
# (가격            3000
#  종류           아이스크림
#  판매일자    2020-02-03
#  반품여부            정상
#  Name: c, dtype: object,
#  가격            3000
#  종류           아이스크림
#  판매일자    2020-02-03
#  반품여부            정상
#  Name: c, dtype: object)

# %% [markdown]
# #### index와 column을 같이 추출

# %%
df_saledays.loc["c","판매일자"] #indexes, columns (다들 복수로 추출함)
# Out:
# '2020-02-03'

# %%
df_saledays.loc[:, "종류": ]
# Out:
#       종류        판매일자 반품여부
# a     과자  2019-12-31   반품
# b     음료  2020-03-02   정상
# c  아이스크림  2020-02-03   정상
# d     과자  2019-12-31   반품

# %% [markdown]
# ### 정렬

# %%
df_saledays.sort_values(by="가격", ascending=True)        # 단일 변수일때
# Out:
#      가격     종류        판매일자 반품여부
# a  1000     과자  2019-12-31   반품
# d  1000     과자  2019-12-31   반품
# b  2000     음료  2020-03-02   정상
# c  3000  아이스크림  2020-02-03   정상

# %%
df_saledays.sort_values(by=["가격","반품여부"],  ascending=[False,True])        # 단일 변수일때
# Out:
#      가격     종류        판매일자 반품여부
# c  3000  아이스크림  2020-02-03   정상
# b  2000     음료  2020-03-02   정상
# a  1000     과자  2019-12-31   반품
# d  1000     과자  2019-12-31   반품

# %% [markdown]
# ### loading dataset from files

# %%
df_california_housing = pd.read_csv("sample_data/california_housing_test.csv")

# %%
df_california_housing.info()                    # 데이터의 정보를 받아 데이터타입을 확인함. 수치형인지 범주형인지
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           3000 non-null   float64
#  1   latitude            3000 non-null   float64
#  2   housing_median_age  3000 non-null   float64
#  3   total_rooms         3000 non-null   float64
#  4   total_bedrooms      3000 non-null   float64
#  5   population          3000 non-null   float64
#  6   households          3000 non-null   float64
#  7   median_income       3000 non-null   float64
#  8   median_house_value  3000 non-null   float64
# dtypes: float64(9)
# memory usage: 211.1 KB

# %%
# df_california_housing[100:105]                    # 100부터 105까지
